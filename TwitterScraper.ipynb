# %% [markdown]
# <a href="https://colab.research.google.com/github/kailukowiak/DATA602_Final_Project/blob/master/TwitterScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twint
# !pip install nest_asyncio

# %%
# Solve compatibility issues with notebooks and RunTime errors.
import nest_asyncio
import twint
nest_asyncio.apply()

# %%
c = twint.Config()
c.Username = "gtconway3d"
c.Store_json = True
c.Output = "/content/drive/My Drive/TwitterScraper/followers_gtconway3d.json"
# c.Hide_output = True


twint.run.Followers(c)
# Out:
# Streaming output truncated to the last 5000 lines.
# SheilaGuilfoyl4
# Pmal8tr
# JRCaskman
# ashalit
# emery20
# WarWolf82521432
# HoeyCodes
# marald79
# jennife76359879
# SeamusMcspears
# vitobattaboom
# LeotisC
# twobuckbill
# MiloNash3
# HassenFawaz
# ttonetom
# JackGabrielse1
# HillearyTed
# spikeinlf
# Ulflundberg3
# treska_david
# pennyphungula25
# freddier1
# helenwheels99
# grace_gilling
# paragwinn
# sabdiazgalasso1
# bevoconnor
# PedsIrving
# DrKurtMD
# MargeMendez
# cucumberfight
# FowletWanda
# ToniMarieDB
# miketroutfanhof
# IHaveSoManyPod
# marcolivierhetu
# bedheaded
# Bert00000
# MoonSha84652917
# jebitor
# AgnesTemesvari
# pascale60
# Samsgram15
# TremblayNichol2
# PABSTCEO
# robinmcstay
# Lesfox10
# KwangKi57716141
# hilarysteele18
# Vetty0312
# Catheri26788373
# tobiastjohnson
# CrystalProClean
# Elaine49668658
# KenMcCaffrey7
# kristin_mack
# bigmac8801
# tocold33
# DanaBra82402609
# Juf_Ongeduld
# janiceburns56
# MuhluriLtd
# PeteMccombs
# juliebattel
# ...
